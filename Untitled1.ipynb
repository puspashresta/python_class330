# %%
import requests
from bs4 import BeautifulSoup

infos=[]
res=requests.get(f'https://www.newegg.com/Video-Cards-Video-Devices/Category/ID-38','html.parser')
daata=res.text
soup=BeautifulSoup(daata,'lxml')
# cs=soup.findAll('div',{'class':'C5TXIP'})
# tags=soup.findAll('div',{'class':'c3e8SH'})
# tags=soup.findAll('a')
# print(soup.prettify())
# containers=soup.find_all('div',{'class':'list-wrap'})
containers=soup.find_all('div',{'class':'item-container'})
containers
# Out:
# [<div class="item-container">
#  <!--product image-->
#  <a class="item-img" href="https://www.newegg.com/gigabyte-radeon-rx-5700-xt-gv-r57xtgaming-oc-8gd/p/N82E16814932208?Item=N82E16814932208">
#  <div class="item-badges">
#  </div>
#  <img alt="GIGABYTE Radeon RX 5700 XT GAMING OC 8G Graphics Card, PCIe 4.0, 8GB 256-Bit GDDR6, GV-R57XTGAMING OC-8GD Video Card" class="lazy-img" data-effect="fadeIn" data-src="//c1.neweggimages.com/NeweggImage/ProductImageCompressAll300/14-932-208-V10.jpg" src="//c1.neweggimages.com/WebResource/Themes/2005/Nest/blank.gif" title="GIGABYTE Radeon RX 5700 XT GAMING OC 8G Graphics Card, PCIe 4.0, 8GB 256-Bit GDDR6, GV-R57XTGAMING OC-8GD Video Card"/>
#  </a>
#  <div class="item-info">
#  <!--brand info-->
#  <div class="item-branding">
#  <a class="item-brand" href="https://www.newegg.com/GIGABYTE/BrandStore/ID-1314">
# ...

# %%
import requests
from bs4 import BeautifulSoup

# infos=[]
res=requests.get(f'https://www.newegg.com/Video-Cards-Video-Devices/Category/ID-38','html.parser')
daata=res.text
soup=BeautifulSoup(daata,'lxml')
containers=soup.find_all('div',{'class':'item-container'})
# container=container.div.div.img("title")
#container=soup.find('a',{'class':'item-brand'})
# container=soup.div.div.a.img['title']
c=len(container)
c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3f52e9d8b145> in <module>
#      10 #container=soup.find('a',{'class':'item-brand'})
#      11 # container=soup.div.div.a.img['title']
# ---> 12 c=len(container)
#      13 c
#
# NameError: name 'container' is not defined

# %%
import requests
from bs4 import BeautifulSoup

infos=[]
res=requests.get(f'https://www.newegg.com/Video-Cards-Video-Devices/Category/ID-38','html.parser')
daata=res.text
soup=BeautifulSoup(daata,'lxml')
# cs=soup.findAll('div',{'class':'C5TXIP'})
# tags=soup.findAll('div',{'class':'c3e8SH'})
# tags=soup.findAll('a')
# print(soup.prettify())
containers=soup.find_all('div',{'class':'item-container'})

file=open('GraphicCard.csv','a')
headers="Brand, ProductName, Shiping Cost\n"
file.write(headers)

for container in containers:
    brand=container.div.div.a.img['item-title']
    title_container=container.findAll('a',{'class':'item-branding'})
    name=title_container[0].text
    charge=container.findAll('li',{'class':'price-ship'})
    delivery_charge=charge[0].text
print('brand'+brand)
print('name'+name)
print('delivery_charge'+delivery_charge)
    
f.write(brand+","+name.replace(",","|")+","+delivery_charge+"\n")
f.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-0e6ce609660f> in <module>
#      17
#      18 for container in containers:
# ---> 19     brand=container.div.div.a.img['item-title']
#      20     title_container=container.findAll('a',{'class':'item-branding'})
#      21     name=title_container[0].text
#
# AttributeError: 'NoneType' object has no attribute 'a'
